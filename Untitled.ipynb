# %%
import torch
print(8)
torch.cuda.is_available()

# %%
import torch
print(torch.version.cuda)               # Should show CUDA 12.8
print(torch.backends.cudnn.version())   # Should show cuDNN version
print(torch.cuda.is_available())        # Should be True  # Should display your GPU model
# Out:
# None
# None
# False
